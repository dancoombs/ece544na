# %%
import sys
sys.path.append("/home/ubuntu/fs/dsb17/code")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, BatchNormalization
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K

import lunaIterator; reload(lunaIterator)
from lunaIterator import lunaIterator

# %matplotlib inline

data_path = '/home/ubuntu/fs/data/dsb17/luna16/'
scan_path = data_path+'scans/'
csv_path = data_path+'csvfiles/annotations.csv'
results_path = data_path+'results/'
# Out:
# Using Theano backend.
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %% [markdown]
# ## Model

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def dice_coef_np(y_true,y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

# %%
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
img_height = 512
img_width = 512

def get_unet():
    inputs = Input((1,img_height, img_width))
    conv1 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(inputs)
    conv1 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(conv1)
    conv1 = BatchNormalization(axis=1)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(pool1)
    conv2 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(conv2)
    conv2 = BatchNormalization(axis=1)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Convolution2D(128, 3, 3, activation='relu', border_mode='same')(pool2)
    conv3 = Convolution2D(128, 3, 3, activation='relu', border_mode='same')(conv3)
    conv3 = BatchNormalization(axis=1)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Convolution2D(256, 3, 3, activation='relu', border_mode='same')(pool3)
    conv4 = Convolution2D(256, 3, 3, activation='relu', border_mode='same')(conv4)
    conv4 = BatchNormalization(axis=1)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Convolution2D(512, 3, 3, activation='relu', border_mode='same')(pool4)
    conv5 = Convolution2D(512, 3, 3, activation='relu', border_mode='same')(conv5)
    conv5 = BatchNormalization(axis=1)(conv5)

    up6 = merge([UpSampling2D(size=(2, 2))(conv5), conv4], mode='concat', concat_axis=1)
    conv6 = Convolution2D(256, 3, 3, activation='relu', border_mode='same')(up6)
    conv6 = Convolution2D(256, 3, 3, activation='relu', border_mode='same')(conv6)
    conv6 = BatchNormalization(axis=1)(conv6)

    up7 = merge([UpSampling2D(size=(2, 2))(conv6), conv3], mode='concat', concat_axis=1)
    conv7 = Convolution2D(128, 3, 3, activation='relu', border_mode='same')(up7)
    conv7 = Convolution2D(128, 3, 3, activation='relu', border_mode='same')(conv7)
    conv7 = BatchNormalization(axis=1)(conv7)

    up8 = merge([UpSampling2D(size=(2, 2))(conv7), conv2], mode='concat', concat_axis=1)
    conv8 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(up8)
    conv8 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(conv8)
    conv8 = BatchNormalization(axis=1)(conv8)

    up9 = merge([UpSampling2D(size=(2, 2))(conv8), conv1], mode='concat', concat_axis=1)
    conv9 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(up9)
    conv9 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(conv9)
    conv9 = BatchNormalization(axis=1)(conv9)

    conv10 = Convolution2D(1, 1, 1, activation='sigmoid')(conv9)

    model = Model(input=inputs, output=conv10)

    model.compile(optimizer=Adam(lr=1.0e-5), loss=dice_coef_loss, metrics=[dice_coef])

    return model

# %% [markdown]
# ## Create Train and Validation Sets

# %%
df = pd.read_csv(csv_path)
num_ids = len(df)
num_train = int(num_ids * 0.75)
num_val = num_ids - num_train
print(num_ids, num_train, num_val)

# idx = df.groupby('seriesuid')['diameter_mm'].transform(max) == df['diameter_mm']
# df_max = df[idx]
# num_ids = len(df_max)
# num_train = int(num_ids * 0.75)
# num_val = num_ids - num_train
# print(num_ids, num_train, num_val)
# Out:
# (1186, 889, 297)

# %%
# TODO: randomize df

df_train = df[:num_train]
df_val = df[num_train:]
print(len(df_train), len(df_val))
# Out:
# (889, 297)

# %%
train_gen = lunaIterator(scan_path, df_train, batch_size=4, shuffle=True)
val_gen = lunaIterator(scan_path, df_val, batch_size=4, shuffle=False)

# %% [markdown]
# ## Train Model

# %%
model = get_unet()
model_checkpoint = ModelCheckpoint(results_path+'unet.hdf5', monitor='val_loss', save_best_only=True)

# %%
# model.summary()

# %%
# model.fit_generator(train_gen, num_train, nb_epoch=1, validation_data=val_gen,
#                     nb_val_samples=num_val, callbacks=[model_checkpoint])

# %%
# model.fit_generator(train_gen, num_train, nb_epoch=20, validation_data=val_gen,
#                     nb_val_samples=num_val, callbacks=[model_checkpoint])

# %% [markdown]
# ## Test Model

# %%
model.load_weights(results_path+'weights_1e-6_01_-0.608.hdf5')

# %%
# look at an output of the model
val_lungs, val_masks = next(val_gen)
out_masks = model.predict(val_lungs, batch_size=4)

for i in range(0, len(out_masks)):
    fig, ax = plt.subplots(1,3,figsize=[10,10])
    ax[0].imshow(val_lungs[i, 0], cmap=plt.cm.gray)
    ax[1].imshow(val_masks[i, 0], cmap=plt.cm.gray)
    ax[2].imshow(out_masks[i, 0], cmap=plt.cm.gray)
    plt.show()

# %% [markdown]
# ## Modifications to model:
#
# 1. Added BatchNormalization(axis=1) between each convolutional layer.
#
# ## Training procedure:
#
# 1. 2 epochs at lr = 1e-5
# 2. 20 epochs at lr = 1e-4
#     - Overfitting seems to begin around epoch 11
#     - val_dice_coef increases until epoch 17
#     - Large reduction (overfitting?) around epoch 19
# 3. 20 epochs at lr = 1e-5
#     - Trined for 13 epochs
#     - Best val_dice_coef (0.607) at epoch 7
#     - train_dice_coef increased very slowly each time (ended at 0.760)
# 4. 5 epochs at lr = 1e-6
#     - No improvement after 3 epochs
#
# New procedure (might need to increase epochs after data aug):
# 1. 2 epochs at 1e-5
# 2. 20 epochs at 1e-4
# 3. 10 epochs at 1e-5
#
# Takes about 12 hours
#
#
# ## To Do:
#
# For the segmenter:
#
# 1. Make sure that there are no nodules with the same id and z coord
# - This dataset contains only lungs where a cancer is predicted, try adding more slices where there is no cancer, this will hopefully reduce false positives in the dsb17 dataset (might not actually be a problem, in observing the output of the dsb17 segmentation there are plenty of blank masks, but extra data shouldn't hurt?)
# - **Data augmentation**, looks like the data can be shifted at least +/- 20 pixels in every direction. It also looks like it can be rotated ~20deg. Horizontal flips?
# - **Dropout** depending on the amount of overfitting after augmentation
# - **Train on all of the data** (add validation set to training set, use procedure above)
# - Try zooming in on lungs (like in tutorial)
# - If ever underfitting (hasn't happened yet) expand the net x2 like in original paper
#
# Improved lung segmenation methods:
# - https://www.kaggle.com/ankasor/data-science-bowl-2017/improved-lung-segmentation-using-watershed/discussion
# - https://www.kaggle.com/arnavkj95/data-science-bowl-2017/lung-segmentation-and-candidate-points-generation/discussion
# - http://ceur-ws.org/Vol-1390/visceralISBI15-5.pdf
#
# ## Ideas:
# Unsupervised Learning
# 1. Use DICOM data for pseudo-labeling
#
# ## Extra Data Sources:
# https://wiki.cancerimagingarchive.net/display/Public/SPIE-AAPM+Lung+CT+Challenge
#
# https://wiki.cancerimagingarchive.net/display/Public/LIDC-IDRI#0c7f41be1bef4e10bb1269756321becb
#
# http://www.via.cornell.edu/lungdb.html
#
# http://www.aylward.org/notes/open-access-medical-image-repositories
#
# ## Pretrained Networks:
# https://github.com/dmlc/mxnet-model-gallery

# %% [markdown]
# ## Long Term Ideas:
#
# 1. Use 2D segmentation to localize a 3D ConvNet
#     - Use a standard volume size that surrounds the nodules and put it into a 3D CNN
# 2. Utilize hand-crafted features in the final ensamble
#     - https://kaggle2.blob.core.windows.net/forum-message-attachments/157939/5838/nejmoa1214726%20(1).pdf?sv=2015-12-11&sr=b&sig=ukjxgiOkADZRhIziAjYd4%2Fba3QsrE73%2FTSnk5XZxz38%3D&se=2017-01-27T22%3A45%3A19Z&sp=r
#     - "Predictors of cancer in the model included older age, female sex, family history of lung cancer, emphysema, larger nodule size, location of the nodule in the upper lobe, part-solid nodule type, lower nodule count, and spiculation"
# 3. VoxResNet
#     - https://arxiv.org/pdf/1608.05895v1.pdf
#
# Ideas from Forum:
# - Autoencoders (unsupervised feature learning): http://ufldl.stanford.edu/tutorial/unsupervised/Autoencoders/
# - "That's one option to do here, maybe do some automated segmentation/annotation and try to replicate it with a 3D ResNet so it can learn some good kernels on the input images. Other option is to use annotations from another dataset (LUNA16 is a good pick there), and try to train a ConvNet to find/classify some nodules, this will also get it to learn some useful features." -r4m0n
# - "So, hints for people trying 3D ConvNets: You need to process more, smaller chunks and give them other tasks than predicting cancer, to train the convolution layers first, then you can move on to the main task." -r4m0n
# - Storage: "I've had some pretty good results with storing processed images/features as Bcolz disk-based arrays, and using them with shuffling on multiples of the chunk size (which you can set). If anyone is interested, I may post a Keras iterator I wrote for it." -r4m0n
